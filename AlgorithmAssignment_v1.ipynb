# %% [markdown]
# ## Problem 1
# Customer who needs to make a delivery needs to know which courier company can does it
# fast (assuming that the shorter the distance, the quicker is the delivery). The application will analyse five
# (5) local courier companies which have their delivery hubs located in various locations in West Malaysia.
# The details of the courier companies and their delivery hubs are given in Table 1.

# %% [markdown]
# ###### Location of the Delivery Hub and Customer Delivery Request

# %%
from IPython.display import IFrame
map = IFrame(src="https://www.google.com/maps/d/embed?mid=1T3sFaHUatAEcDfTHWqZqWUFK2csTpqmc&hl=en", width=800, height=600)
display(map)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://www.google.com/maps/d/embed?mid=1T3sFaHUatAEcDfTHWqZqWUFK2csTpqmc&hl=en"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Data

# %%
import pandas as pd
import googlemaps

#Perform request to use the Google Maps API web service
API_key = 'AIzaSyBeaEjFijMcS1c_Zq4j8p_Wpdd0bpfpsaU'#enter Google Maps API key
gmaps = googlemaps.Client(key=API_key)

#Read CSV file into data frame named 'df'
#change seperator (sep e.g. ',') type if necessary
courierCompanyData = pd.read_csv('AlgorithmDataCourier.csv')
custDeliveryData = pd.read_csv('AlgorithmDataCustomer.csv')


#print courier company data
courierCompanyData
# Out:
#       Courier Company    Delivery Hub  Latitude   Longitude
# 0  City-link Express       Port Klang  3.031992  101.373441
# 1           Pos Laju   Petaling Jaya   3.112924  101.639826
# 2              GDEX ,      Batu Caves  3.265155  101.680248
# 3                J&T           Kajang  2.944121  101.790152
# 4               DHL      Sungai Buloh  3.212723  101.574673

# %%
#print custoemr delivery request data
custDeliveryData
# Out:
#      Customer       Origin  Latitude-Origin  Longitude-Origin     Destination  \
# 0  Customer 1       Rawang         3.361540        101.563182  Bukit Jelutong
# 1  Customer 2  Subang Jaya         3.049398        101.585466     Puncak Alam
# 2  Customer 3       Ampang         3.141856        101.761586       Cyberjaya
#
#    Latitude-Destination  Longitude-Destination
# 0              3.100017             101.530715
# 1              3.227994             101.427304
# 2              2.918870             101.652518

# %%
#print the full data
fullData = pd.read_csv('AlgorithmDataFull.csv')
fullData
# Out:
#     Cust       Origin  Latitude-Origin  Longitude-Origin    Delivery Hub  \
# 0      1       Rawang         3.361540        101.563182      Port Klang
# 1      1       Rawang         3.361540        101.563182  Petaling Jaya
# 2      1       Rawang         3.361540        101.563182      Batu Caves
# 3      1       Rawang         3.361540        101.563182          Kajang
# 4      1       Rawang         3.361540        101.563182    Sungai Buloh
# 5      2  Subang Jaya         3.049398        101.585466      Port Klang
# 6      2  Subang Jaya         3.049398        101.585466  Petaling Jaya
# 7      2  Subang Jaya         3.049398        101.585466      Batu Caves
# 8      2  Subang Jaya         3.049398        101.585466          Kajang
# 9      2  Subang Jaya         3.049398        101.585466    Sungai Buloh
# 10     3       Ampang         3.141856        101.761586      Port Klang
# 11     3       Ampang         3.141856        101.761586  Petaling Jaya
# 12     3       Ampang         3.141856        101.761586      Batu Caves
# 13     3       Ampang         3.141856        101.761586          Kajang
# 14     3       Ampang         3.141856        101.761586    Sungai Buloh
#
#     Latitude-DH  Longitude-DH     Destination  Latitude-Destination  \
# 0      3.031992    101.373441  Bukit Jelutong              3.100017
# 1      3.112924    101.639826  Bukit Jelutong              3.100017
# 2      3.265155    101.680248  Bukit Jelutong              3.100017
# 3      2.944121    101.790152  Bukit Jelutong              3.100017
# 4      3.212723    101.574673  Bukit Jelutong              3.100017
# 5      3.031992    101.373441     Puncak Alam              3.227994
# 6      3.112924    101.639826     Puncak Alam              3.227994
# 7      3.265155    101.680248     Puncak Alam              3.227994
# 8      2.944121    101.790152     Puncak Alam              3.227994
# 9      3.212723    101.574673     Puncak Alam              3.227994
# 10     3.031992    101.373441       Cyberjaya              2.918870
# 11     3.112924    101.639826       Cyberjaya              2.918870
# 12     3.265155    101.680248       Cyberjaya              2.918870
# 13     2.944121    101.790152       Cyberjaya              2.918870
# 14     3.212723    101.574673       Cyberjaya              2.918870
#
#     Longitude-Destination
# 0              101.530715
# 1              101.530715
# 2              101.530715
# 3              101.530715
# 4              101.530715
# 5              101.427304
# 6              101.427304
# 7              101.427304
# 8              101.427304
# 9              101.427304
# 10             101.652518
# 11             101.652518
# 12             101.652518
# 13             101.652518
# 14             101.652518

# %% [markdown]
# ### Calculate Distance

# %%
#store calculated distances
totalDistanceList = []
distance1List = []
distance2List = []

origin_Lat = fullData['Latitude-Origin']
origin_Long = fullData['Longitude-Origin']
dh_Lat = fullData['Latitude-DH']
dh_Long = fullData['Longitude-DH']
dest_Lat = fullData['Latitude-Destination']
dest_Long = fullData['Longitude-Destination']

origin = (origin_Lat, origin_Long)
del_hub = (dh_Lat, dh_Long)
destination = (dest_Lat, dest_Long)

for i in range(len(fullData['Latitude-Origin'])):
    origin = (origin_Lat[i], origin_Long[i])
    del_hub = (dh_Lat[i], dh_Long[i])
    destination = (dest_Lat[i], dest_Long[i])
    
    #calculate distance
    distance1 = gmaps.distance_matrix(origin, del_hub, mode='driving')["rows"][0]["elements"][0]["distance"]["value"]
    distance2 = gmaps.distance_matrix(del_hub, destination, mode='driving')["rows"][0]["elements"][0]["distance"]["value"]
    total_distance = distance1 + distance2
    
    distance1List.append(distance1/1000)
    distance2List.append(distance2/1000)
    totalDistanceList.append(total_distance/1000)
    
fullData["Distance1 (Km)"] = distance1List
fullData["Distance2 (Km)"] = distance2List
fullData["Total Distance (Km)"] = totalDistanceList

# %%
fullData.to_csv('AlgoCalculated_Distances.csv', sep=',', index=None, header= ['Cust','Origin','Latitude-Origin','Longitude-Origin','Delivery Hub','Latitude-DH','Longitude-DH','Destination','Latitude-Destination','Longitude-Destination','Distance1 (Km)','Distance2 (Km)','Total Distance (Km)'])

# %%
calc_distance = pd.read_csv('AlgoCalculated_Distances.csv')
calc_distance
# Out:
#     Cust       Origin  Latitude-Origin  Longitude-Origin    Delivery Hub  \
# 0      1       Rawang         3.361540        101.563182      Port Klang
# 1      1       Rawang         3.361540        101.563182  Petaling Jaya
# 2      1       Rawang         3.361540        101.563182      Batu Caves
# 3      1       Rawang         3.361540        101.563182          Kajang
# 4      1       Rawang         3.361540        101.563182    Sungai Buloh
# 5      2  Subang Jaya         3.049398        101.585466      Port Klang
# 6      2  Subang Jaya         3.049398        101.585466  Petaling Jaya
# 7      2  Subang Jaya         3.049398        101.585466      Batu Caves
# 8      2  Subang Jaya         3.049398        101.585466          Kajang
# 9      2  Subang Jaya         3.049398        101.585466    Sungai Buloh
# 10     3       Ampang         3.141856        101.761586      Port Klang
# 11     3       Ampang         3.141856        101.761586  Petaling Jaya
# 12     3       Ampang         3.141856        101.761586      Batu Caves
# 13     3       Ampang         3.141856        101.761586          Kajang
# 14     3       Ampang         3.141856        101.761586    Sungai Buloh
#
#     Latitude-DH  Longitude-DH     Destination  Latitude-Destination  \
# 0      3.031992    101.373441  Bukit Jelutong              3.100017
# 1      3.112924    101.639826  Bukit Jelutong              3.100017
# 2      3.265155    101.680248  Bukit Jelutong              3.100017
# 3      2.944121    101.790152  Bukit Jelutong              3.100017
# 4      3.212723    101.574673  Bukit Jelutong              3.100017
# 5      3.031992    101.373441     Puncak Alam              3.227994
# 6      3.112924    101.639826     Puncak Alam              3.227994
# 7      3.265155    101.680248     Puncak Alam              3.227994
# 8      2.944121    101.790152     Puncak Alam              3.227994
# 9      3.212723    101.574673     Puncak Alam              3.227994
# 10     3.031992    101.373441       Cyberjaya              2.918870
# 11     3.112924    101.639826       Cyberjaya              2.918870
# 12     3.265155    101.680248       Cyberjaya              2.918870
# 13     2.944121    101.790152       Cyberjaya              2.918870
# 14     3.212723    101.574673       Cyberjaya              2.918870
#
#     Longitude-Destination  Distance1 (Km)  Distance2 (Km)  Total Distance (Km)
# 0              101.530715          70.218          28.814               99.032
# 1              101.530715          42.783          20.457               63.240
# 2              101.530715          24.742          36.345               61.087
# 3              101.530715          75.735          49.207              124.942
# 4              101.530715          26.782          27.176               53.958
# 5              101.427304          39.679          30.570               70.249
# 6              101.427304          14.021          41.995               56.016
# 7              101.427304          35.906          41.104               77.010
# 8              101.427304          35.215          70.745              105.960
# 9              101.427304          24.145          23.378               47.523
# 10             101.652518          55.724          56.052              111.776
# 11             101.652518          19.224          34.331               53.555
# 12             101.652518          23.705          48.717               72.422
# 13             101.652518          27.763          24.629               52.392
# 14             101.652518          30.961          52.558               83.519

# %% [markdown]
# ### Find the least distance that the parcel has to travel for each customer using every courier company

# %%
#quick sort algorithm
def partition(arr, hub, start, end):
    #make the last element as the pivot
    i = (start- 1)
    pivot = arr[end]

    for j in range(start, end):

        # If current element is smaller than or equal to pivot
        if arr[j] <= pivot:
            # increment index of smaller element
            i = i + 1
            arr[i], arr[j] = arr[j], arr[i]
            hub[i], hub[j] = hub[j], hub[i]

    arr[i + 1], arr[end] = arr[end], arr[i + 1]
    hub[i + 1], hub[end] = hub[end], hub[i + 1]
    return (i + 1)

# Function to do Quick sort

def quickSort(arr, hub, start, end):
    if len(arr) == 1:
        return arr
    if start < end:
        # pi is partitioning index, arr[p] is now at right place
        pi = partition(arr, hub, start, end)

        # Separately sort elements before
        # partition and after partition
        quickSort(arr, hub, start, pi - 1)
        quickSort(arr, hub, pi + 1, end)

#initialize
customers = calc_distance['Cust']   
total_distances = calc_distance['Total Distance (Km)']
del_hub = calc_distance['Delivery Hub']
n = len(total_distances)

#initialize sorted hub
customer1 = []
hub1 = []
customer2 = []
hub2 = []
customer3 = []
hub3 = []

for i in range(len(customers)):
    if customers[i] == 1:
        customer1.append(total_distances[i])
        hub1.append(del_hub[i])
    elif customers[i] == 2:
        customer2.append(total_distances[i])
        hub2.append(del_hub[i])
    elif customers[i] == 3:
        customer3.append(total_distances[i])
        hub3.append(del_hub[i])

quickSort(customer1, hub1, 0, len(customer1) - 1)
quickSort(customer2, hub2, 0, len(customer2) - 1) 
quickSort(customer3, hub3, 0, len(customer3) - 1)

# %% [markdown]
# ### Display after sort

# %%
couriers1 = []
couriers2 = []
couriers3 = []

def deliveryHub(hub, couriers):
    for delivery_hub in hub:
        if delivery_hub == 'Port Klang':
            couriers.append('City-link Express')
        elif delivery_hub == 'Petaling Jaya':
            couriers.append('Pos Laju')
        elif delivery_hub == 'Batu Caves':
            couriers.append('GDEX')
        elif delivery_hub == 'Kajang':
            couriers.append('J&T')
        elif delivery_hub == 'Sungai Buloh':
            couriers.append('DHL')

deliveryHub(hub1, couriers1)
deliveryHub(hub2, couriers2)
deliveryHub(hub3, couriers3)

print('Customer 1: Distance and Delivery Hub')
print(customer1)
print(hub1)
print(couriers1)

print('\nCustomer 2: Distance and Delivery Hub')
print(customer2)
print(hub2)
print(couriers2)

print('\nCustomer 1: Distance and Delivery Hub')
print(customer3)
print(hub3)
print(couriers3)
# Out:
# Customer 1: Distance and Delivery Hub
# [53.958, 61.087, 63.24, 99.032, 124.942]
# ['Sungai Buloh', 'Batu Caves', 'Petaling Jaya ', 'Port Klang', 'Kajang']
# ['DHL', 'GDEX', 'City-link Express', 'J&T']
#
# Customer 2: Distance and Delivery Hub
# [47.523, 56.016, 70.249, 77.01, 105.96]
# ['Sungai Buloh', 'Petaling Jaya ', 'Port Klang', 'Batu Caves', 'Kajang']
# ['DHL', 'City-link Express', 'GDEX', 'J&T']
#
# Customer 1: Distance and Delivery Hub
# [52.392, 53.555, 72.422, 83.519, 111.776]
# ['Kajang', 'Petaling Jaya ', 'Batu Caves', 'Sungai Buloh', 'Port Klang']
# ['J&T', 'GDEX', 'DHL', 'City-link Express']

# %% [markdown]
# ### Plot line between the destinations before and after algorithm (define in 4) is chosen

# %% [markdown]
# #### Customer 1

# %%
import folium
m = folium.Map(location=[3.0738, 101.5183],
               zoom_start=15)

place_lat = [3.361540, 3.212723, 3.100017]
place_lng = [101.563182, 101.574673, 101.530715]

points = []
for i in range(len(place_lat)):
    points.append([place_lat[i], place_lng[i]])

for index,lat in enumerate(place_lat):
    folium.Marker([lat, 
                   place_lng[index]],
                 icon = folium.Icon(color='green',icon='circle')).add_to(m)
folium.PolyLine(points, color='red').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f5c980222694eb1a4c04d4aa5752ce9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f5c980222694eb1a4c04d4aa5752ce9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f5c980222694eb1a4c04d4aa5752ce9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f5c980222694eb1a4c04d4aa5752ce9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B3.0738%2C%20101.5183%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
#3.049398	101.585466 3.212723	101.574673 3.227994	101.427304
place_lat = [3.049398, 3.212723, 3.227994]
place_lng = [101.585466, 101.574673, 101.427304]

points = []
for i in range(len(place_lat)):
    points.append([place_lat[i], place_lng[i]])

for index,lat in enumerate(place_lat):
    folium.Marker([lat, 
                   place_lng[index]],
                 icon = folium.Icon(color='purple',icon='circle')).add_to(m)
folium.PolyLine(points, color='blue').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f5c980222694eb1a4c04d4aa5752ce9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f5c980222694eb1a4c04d4aa5752ce9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f5c980222694eb1a4c04d4aa5752ce9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f5c980222694eb1a4c04d4aa5752ce9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B3.0738%2C%20101.5183%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
#3.141856	101.761586	2.944121	101.7901522.918870	101.652518

place_lat = [3.141856, 2.944121, 2.918870]
place_lng = [101.761586, 101.574673, 101.652518]

points = []
for i in range(len(place_lat)):
    points.append([place_lat[i], place_lng[i]])

for index,lat in enumerate(place_lat):
    folium.Marker([lat, 
                   place_lng[index]],
                 icon = folium.Icon(color='darkred',icon='circle')).add_to(m)
folium.PolyLine(points, color='black').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f5c980222694eb1a4c04d4aa5752ce9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f5c980222694eb1a4c04d4aa5752ce9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f5c980222694eb1a4c04d4aa5752ce9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f5c980222694eb1a4c04d4aa5752ce9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B3.0738%2C%20101.5183%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
