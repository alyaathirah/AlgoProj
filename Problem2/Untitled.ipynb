# %% [markdown]
# **1. Extract information from three (3) articles from online news websites that have published stories
# related to each courier company.**

# %% [markdown]
# **2. Compare words in the web pages with the positive, negative and neutral English words using a
# String-Matching algorithm**

# %%
import urllib.request, urllib.error, urllib.parse
import web
import trie

url = ['https://www.dailymail.co.uk/news/article-2889112/A-million-parcels-stuck-depots-failure-courier-City-Link.html', 'https://www.independent.co.uk/news/business/news/city-link-hopelessly-insolvent-christmas-court-told-a6723556.html',
         'https://www.thestar.com.my/business/business-news/2007/02/02/courier-tieup-sri-lanka-firm-appoints-citylink-express']

tword = []
tstop = []
neu = []
pov = []
neg = []

for i in url:
    print('Article', i,
          '\n-------------------------------------------------------\n')
    response = urllib.request.urlopen(i)
    html = response.read()
    text = web.stripTags(html).lower()

    fullwordlist = web.stripNonAlphaNum(text)
    wordlist1 = web.remove(fullwordlist)
    stopwordCount = web.calculateStopWord(wordlist1)  #calculate
    wordlist2 = web.removeStopwords(wordlist1, web.stopwords)
    dictionary = web.wordListToFreqDict(wordlist2)
    sorteddict = web.sortFreqDict(dictionary)

    #for s in sorteddict:
    #    print(str(s))

    sumWord = 0
    for i in dictionary.values():
        sumWord += i
    print("Total Words:", sumWord)
    print("Total Stop Words:", stopwordCount, "\n")
    tword.append(sumWord)
    tstop.append(stopwordCount)

    tr = trie.Trie()

    for key, value in dictionary.items():
        tr.insert(key, value)

    key1 = []
    #badWord
    with open("badWord.txt", "r") as a_file:
        total = []
        for line in a_file:
            for currentline in line.strip().split(', '):
                output = tr.search(currentline)
                if output:
                    x = output[0]
                    y = output[1]
                    print(x)
                    key1 += x
                    total.append(y)

        sumBad = 0
        for i in total:
            sumBad += i
        print('\nTotal Negative Words: ', sumBad, '\n')
        neg.append(sumBad)

    #postiveWord
    with open("positiveWord.txt", "r") as b_file:
        total = []
        for line in b_file:
            for currentline in line.strip().split(', '):
                output = tr.search(currentline)
                if output:
                    x = output[0]
                    y = output[1]
                    print(x)
                    key1 += x
                    total.append(y)

        sumPos = 0
        for i in total:
            sumPos += i
        print('\nTotal Positive Words: ', sumPos)
        pov.append(sumPos)

    for j in key1:
        key = str(j)
        dictionary.pop(key)
    #print(dictionary.items())

    sumNeu = 0
    for key, value in dictionary.items():
        sumNeu += value
    neutralWord = list(dictionary.keys())
    #print(neutralWord)
    #print(dictionary.keys())
    print('Total Neutral Words: ', sumNeu, '\n')
    neu.append(sumNeu)
# Out:
# Article https://www.dailymail.co.uk/news/article-2889112/A-million-parcels-stuck-depots-failure-courier-City-Link.html
# -------------------------------------------------------
#
# Total Words: 7686
# Total Stop Words: 3864
#
# ['terrible']
# ['bad']
# ['late', 'latex']
# ['failed', 'failure']
# ['danger', 'dangerous']
# ['stuck']
# ['poor']
# ['delay', 'delays']
# ['suffered', 'suffering']
# ['dead', 'deadly']
# ['burden']
#
# Total Negative Words:  45
#
# ['great', 'greatest']
# ['able']
# ['accept', 'accepting']
#
# Total Positive Words:  8
# Total Neutral Words:  7633
#
# Article https://www.independent.co.uk/news/business/news/city-link-hopelessly-insolvent-christmas-court-told-a6723556.html
# -------------------------------------------------------
#
# Total Words: 3417
# Total Stop Words: 665
#
# ['bad']
# ['late']
# ['failing', 'failure']
# ['delays']
# ['collapsed']
# ['dismissals']
# ['deadline']
# ['hopelessly']
#
# Total Negative Words:  32
#
# ['boost']
#
# Total Positive Words:  1
# Total Neutral Words:  3384
#
# Article https://www.thestar.com.my/business/business-news/2007/02/02/courier-tieup-sri-lanka-firm-appoints-citylink-express
# -------------------------------------------------------
#
# Total Words: 11168
# Total Stop Words: 1822
#
# ['badge', 'badminton']
# ['fail', 'failed']
# ['delay']
# ['collapsed']
# ['dead']
#
# Total Negative Words:  12
#
# ['greatly']
#
# Total Positive Words:  2
# Total Neutral Words:  11154

# %%
import pandas as pd

print('CityLink Express\n')
# intialise data of lists.
data = {'Article No.':['1', '2', '3'],
        'Word Counts':tword,
        'Stop Word':tstop,
        'Positive Word':pov,
        'Negative Word':neg}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
# CityLink Express
#
#   Article No.  Word Counts  Stop Word  Positive Word  Negative Word
# 0           1         7686       3864              8             45
# 1           2         3417        665              1             32
# 2           3        11168       1822              2             12

# %%
totalPov = 0
totalNeg = 0

for i in pov:
    totalPov += i
    
for j in neg:
    totalNeg += j
    
print("Conclusion: ")
if totalPov > totalNeg:
    print("The articles give positive sentiment.")
else:
    print("The articles give negative sentiment.")
# Out:
# Conclusion:
# The articles give negative sentiment.
